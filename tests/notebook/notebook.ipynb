# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
import dexc.autoinstall

# %%
print(dexc.get_ipython())
# Out:
# AttributeError: module 'dexc' has no attribute 'get_ipython'
# at class InteractiveShell in IPython/core/interactiveshell.py:3579 as IPython.core.interactiveshell
#   3576     if async_:
#   3577         await eval(code_obj, self.user_global_ns, self.user_ns)
#   3578     else:
#   3579         exec(code_obj, self.user_global_ns, self.user_ns)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   3580 finally:
#   3581     # Reset our crash handler in place
#
# in 1343607603.py:1 as 1343607603

# %%
reg(
# Out:
# SyntaxError: incomplete input (268872376.py, line 1)
# at class InteractiveShell in IPython/core/interactiveshell.py:3308 as IPython.core.interactiveshell
#   3305 with self.display_trap:
#   3306     # Compile to bytecode
#   3307     try:
#   3308         code_ast = compiler.ast_parse(cell, filename=cell_name)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   3309     except self.custom_exceptions as e:
#   3310         etype, value, tb = sys.exc_info()
#
# at function ast_parse in IPython/core/compilerop.py:86 as IPython.core.compilerop
#   84     Arguments are exactly the same as ast.parse (in the standard library),
#   85     and are passed to the built-in compile function."""
#   86     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   87
#   88 def reset_compiler_flags(self):

# %%
raise Exception
# Out:
# Exception:
# at class InteractiveShell in IPython/core/interactiveshell.py:3579 as IPython.core.interactiveshell
#   3576     if async_:
#   3577         await eval(code_obj, self.user_global_ns, self.user_ns)
#   3578     else:
#   3579         exec(code_obj, self.user_global_ns, self.user_ns)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   3580 finally:
#   3581     # Reset our crash handler in place
#
# in 3275756190.py:1 as 3275756190
