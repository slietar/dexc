# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import dexc.autoinstall

# %%
def a():
  raise Exception('hello there')

a()
# Out:
# Exception: hello there
#   in module IPython.core.interactiveshell
#   at module                                                                             Cell In[2]:4
#     1 def a():
#     2   raise Exception('hello there')
#     3
#     4 a()
#       ^^^
#   at a                                                                                  Cell In[2]:2
#     1 def a():
#     2   raise Exception('hello there')
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     3
#     4 a()

# %%
import sys
from IPython.core import ultratb
sys.excepthook = ultratb.ColorTB()
# Out:
# ┌──── Warning ─────────────────────────────────────────────────────────────────────────────────────┐
# │ DeprecationWarning                                                                               │
# │   Deprecated since IPython 9.0 use FormattedTB directly ColorTB is just an alias                 │
# │                                                                                                  │
# │   in module ipykernel_launcher                                                                   │
# │   in module traitlets.config.application                                                         │
# │   in module ipykernel.kernelapp                                                                  │
# │   in module tornado.platform.asyncio                                                             │
# │   in modules asyncio.* [3 frames]                                                                │
# ...

# %%
print(f'\033]8;;https://google.com\033\\Text\033]8;;\033\\')
# Out:
# ]8;;https://google.com\Text]8;;\

# %%
from dexc_tests.t01 import main as t01
t01()
# Out:
# Exception
#   in module IPython.core.interactiveshell
#   at module                                                                             Cell In[4]:2
#     1 from dexc_tests.t01 import main as t01
#     2 t01()
#       ^^^^^
#   at main                                                                        dexc_tests/t01.py:2
#     1 def main():
#     2   raise Exception
#         ^^^^^^^^^^^^^^^

# %%
foo)
# Out:
# SyntaxError: unmatched ')'
#   in modules IPython.core.* [2 frames]
#   at file                                                                               Cell In[5]:1
#     1 foo)
#          ^
